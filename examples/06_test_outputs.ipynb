# %%
import numpy as np
from openTSNE.tsne import TSNEEmbedding, gradient_descent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 from openTSNE.tsne import TSNEEmbedding, gradient_descent
#
# File ~/EngageSmarter/openTSNE-slim/openTSNE/__init__.py:1
# ----> 1 from .tsne import TSNE, TSNEEmbedding, PartialTSNEEmbedding, OptimizationInterrupt
#       2 from .version import __version__
#
# File ~/EngageSmarter/openTSNE-slim/openTSNE/tsne.py:15
#      12 except Exception:  # pragma: no cover - allow slim runtime without sklearn
#      13     BaseEstimator = object
# ---> 15 from openTSNE import _tsne
#      16 from openTSNE import initialization as initialization_scheme
#      17 from openTSNE.affinity import Affinities, MultiscaleMixture
#
# ...

# %%
X = np.load("X.npy")
X_1 = np.load("X_1.npy")
X_1_embedded = np.load("X_1_embedded.npy")


model = TSNE(n_components=2, random_state=42).fit(X)
X_1_embedded_2 = model.transform(X_1)

# Check if the two embeddings are close
np.allclose(X_1_embedded, X_1_embedded_2)

# Check if the two embeddings are the same
np.array_equal(X_1_embedded, X_1_embedded_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 X_1 = np.load("X_1.npy")
#       3 X_1_embedded = np.load("X_1_embedded.npy")
# ----> 6 model = TSNE(n_components=2, random_state=42).fit(X)
#       7 X_1_embedded_2 = model.transform(X_1)
#       9 # Check if the two embeddings are close
#
# NameError: name 'TSNE' is not defined
